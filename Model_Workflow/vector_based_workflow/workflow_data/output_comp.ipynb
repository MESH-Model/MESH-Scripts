# %%
import pandas as pd

# %%
old  = pd.read_csv("C:/Users/5600x/Documents/Basin_average_water_balance_old.csv")
new  = pd.read_csv("C:/Users/5600x/Documents/Basin_average_water_balance.csv")
QGIS = pd.read_csv("C:/Users/5600x/Documents/Basin_average_water_balance_112510am.csv")

# %%
diff = pd.DataFrame()
newr = round(new,2)
QGISr = round(QGIS,2)
oldr = round(old,2)
for i in newr.columns:
    diff[i] = abs((newr[i]-QGISr[i]))

# %%
diff
# Out:
#                 YEAR             JDAY          PRECACC            ETACC  \
# 0                  0                0              0.0             0.08
# 1                  0                0              0.0             0.13
# 2                  0                0              0.0             0.49
# 3                  0                0              0.0             1.18
# 4                  0                0              0.0             1.17
# ..               ...              ...              ...              ...
# 360                0                0              0.0            58.70
# 361                0                0              0.0            58.73
# 362                0                0              0.0            58.72
# 363                0                0              0.0            58.79
# 364                0                0              0.0            58.81
#
#               ROFACC        OVRFLWACC        LATFLWACC      DRAINSOLACC  \
# ...

# %%
newr
# Out:
#                 YEAR             JDAY          PRECACC            ETACC  \
# 0               1980                2             2.94             0.35
# 1               1980                3             3.94             0.58
# 2               1980                4            25.09             1.18
# 3               1980                5            35.01             2.25
# 4               1980                6            35.02             2.66
# ..               ...              ...              ...              ...
# 360             1980              362          1614.74           576.50
# 361             1980              363          1614.74           576.86
# 362             1980              364          1620.56           576.88
# 363             1980              365          1620.78           577.31
# 364             1980              366          1620.78           577.62
#
#               ROFACC        OVRFLWACC        LATFLWACC      DRAINSOLACC  \
# ...

# %%
QGISr
# Out:
#                 YEAR             JDAY          PRECACC            ETACC  \
# 0               1980                2             2.94             0.27
# 1               1980                3             3.94             0.45
# 2               1980                4            25.09             0.69
# 3               1980                5            35.01             1.07
# 4               1980                6            35.02             1.49
# ..               ...              ...              ...              ...
# 360             1980              362          1614.74           517.80
# 361             1980              363          1614.74           518.13
# 362             1980              364          1620.56           518.16
# 363             1980              365          1620.78           518.52
# 364             1980              366          1620.78           518.81
#
#               ROFACC        OVRFLWACC        LATFLWACC      DRAINSOLACC  \
# ...
